# %%
import pandas as pd
token_results_df = pd.read_parquet("run_2024_06_17/2024_6_17T19_31_38.parquet")
token_results_df
# Out:
#                                  DOI token_vocabulary  token_frac_refs  \
# 0          10.1108/01443580010342384      [Launhardt]         0.393443
# 1          10.1108/01443579510080409           [Time]         0.351351
# 2          10.1108/02683949610124771        [Barling]         0.352941
# 3          10.1108/01443589910284417          [India]         0.419355
# 4          10.1108/02656719410051643       [supplied]         0.586207
# ...                              ...              ...              ...
# 464680  10.1007/978-94-017-2823-2_17           [Math]         0.468750
# 464681   10.1007/978-94-017-1019-0_1           [Chem]         0.425000
# 464682  10.1007/978-0-306-47593-1_44           [Mogi]         0.463415
# 464683  10.1007/978-94-017-2823-2_32      [Doplicher]         0.448276
# 464684   10.1007/978-94-017-3215-4_2           [Erez]         0.371681
#
#         total_processed_ref_len  cleaned_references_length        work_type  \
# ...

# %%
test = token_results_df.copy()
def get_inequality(row):
    get_inequal = False
    if row['total_processed_ref_len'] != row['cleaned_references_length']:
        get_inequal = True
    return get_inequal
test['unequal'] = test.apply(get_inequality, axis=1)
test
# Out:
#                                  DOI token_vocabulary  token_frac_refs  \
# 0          10.1108/01443580010342384      [Launhardt]         0.393443
# 1          10.1108/01443579510080409           [Time]         0.351351
# 2          10.1108/02683949610124771        [Barling]         0.352941
# 3          10.1108/01443589910284417          [India]         0.419355
# 4          10.1108/02656719410051643       [supplied]         0.586207
# ...                              ...              ...              ...
# 464680  10.1007/978-94-017-2823-2_17           [Math]         0.468750
# 464681   10.1007/978-94-017-1019-0_1           [Chem]         0.425000
# 464682  10.1007/978-0-306-47593-1_44           [Mogi]         0.463415
# 464683  10.1007/978-94-017-2823-2_32      [Doplicher]         0.448276
# 464684   10.1007/978-94-017-3215-4_2           [Erez]         0.371681
#
#         total_processed_ref_len  cleaned_references_length        work_type  \
# ...

# %%
test[(test.unequal == True) & (test.cleaned_references_length < 25)]
# Out:
#                                     DOI  \
# 3258           10.4103/0973-8398.107563
# 9715               10.2139/ssrn.2181050
# 10868              10.2139/ssrn.2164464
# 39210               10.2139/ssrn.917396
# 39273              10.2139/ssrn.1443933
# 97106         10.1080/08905490008583494
# 101591        10.1080/12265080008449794
# 115939        10.1080/03081067808717141
# 123996  10.1590/s1516-14982006000200005
# 261767         10.1177/0272684x21995672
# 278373    10.1080/09540962.2020.1816652
# 339011             10.2139/ssrn.3200900
# 343000             10.2139/ssrn.3181785
# 346527             10.2139/ssrn.3144115
# 382260         10.4103/2249-4987.192214
# 388943             10.2139/ssrn.4575450
# 409966        10.1002/9781119090427.ch2
# 412272         10.4103/0971-9784.148312
# 417389             10.2139/ssrn.2573304
# 449174             10.2139/ssrn.2326335
# 451650             10.2139/ssrn.2309145
# 452009             10.2139/ssrn.2304393
#
# ...

# %%
s.head(2)
# Out:
#                          DOI token_vocabulary  token_frac_refs  \
# 0  10.1108/01443580010342384      [Launhardt]         0.393443
# 1  10.1108/01443579510080409           [Time]         0.351351
#
#    total_processed_ref_len  cleaned_references_length        work_type  \
# 0                       61                         61  journal-article
# 1                       37                         37  journal-article
#
#                              author flag  \
# 0                [backhaus, ursula]   No
# 1  [kumar, ashok, motwani, jaideep]   No
#
#                                                title
# 0  An engineer’s view of economics: Wilhelm Launh...
# 1  A methodology for assessing time‐based competi...

# %%
weird_tokens = token_results_df[token_results_df.token_frac_refs >= 1].sort_values('token_frac_refs', ascending=False)

# %%
weird_tokens
# Out:
#                                          DOI                token_vocabulary  \
# 450409                   10.2514/6.1996-3998                          [Node]
# 253782            10.1108/jitlp-01-2021-0001                           [the]
# 213151  10.30687/annor/2385-3042/2022/01/018                           [the]
# 265228                    10.5817/ah2020-2-4                           [SAV]
# 405742               10.59743/jau.v27i1.1458                            [بن]
# ...                                      ...                             ...
# 238104               10.15302/j-fase-2021430  [span, class, magtechrefsourc]
# 238123                 10.47615/issej.952461                      [Referans]
# 238422                  10.2139/ssrn.3153346                         [EuLfs]
# 238498                  10.16899/jcm.1014181                      [Referans]
# 260426                     10.3390/s21062192                         [https]
#
# ...

# %%
weird_tokens.head(50)
# Out:
#                                          DOI token_vocabulary  \
# 450409                   10.2514/6.1996-3998           [Node]
# 253782            10.1108/jitlp-01-2021-0001            [the]
# 213151  10.30687/annor/2385-3042/2022/01/018            [the]
# 265228                    10.5817/ah2020-2-4            [SAV]
# 405742               10.59743/jau.v27i1.1458             [بن]
# 220060                10.34118/sej.v3i1.1421             [بن]
# 229891             10.1177/10482911221079056            [MPP]
# 451354                   10.2514/6.1992-2294          [ERROR]
# 383008           10.1007/978-3-476-02779-5_2          [Heise]
# 358810             10.1007/s00383-017-4160-x       [Japanese]
# 189495           10.2991/978-2-38476-004-6_5    [Jia, Pingwa]
# 21441            10.1007/978-3-642-28738-1_1            [Mie]
# 412815           10.1136/bmjopen-2014-006572             [of]
# 362380             10.3103/s0146411623050085        [Nechval]
# ...

# %%
weird_tokens.shape
# Out:
# (4280, 9)

# %%
weird_tokens[weird_tokens.flag == "Yes"].head(50)
# Out:
#                                          DOI token_vocabulary  \
# 362380             10.3103/s0146411623050085        [Nechval]
# 291170             10.9787/kjbs.2020.52.s.73           [Park]
# 323463             10.1186/s13662-019-2058-8            [Kim]
# 332203           10.2174/1874844901805010036         [Sharma]
# 258636              10.2478/actatr-2019-0003           [Luca]
# 105418                    10.1007/bf02798611          [Linko]
# 218346       10.4018/978-1-6684-5109-0.ch003        [Popescu]
# 369277      10.1007/978-3-319-28099-8_2222-1         [Markey]
# 291589        10.1007/978-3-319-24612-3_2222         [Markey]
# 243241        10.47992/ijaeml.2581.7000.0106         [Aithal]
# 291681        10.1007/978-3-319-24612-3_2221         [Markey]
# 373170      10.1007/978-3-319-28099-8_2221-1         [Markey]
# 60442              10.1134/s1061830911020033      [Artamonov]
# 238778          10.1007/978-3-030-82199-9_48     [Boranbayev]
# ...

# %%
cleaned_results_df = token_results_df[token_results_df.token_frac_refs < 1].sort_values('token_frac_refs', ascending=False)

# %%
cleaned_results_df.work_type.unique()
# Out:
# array(['posted-content', 'book-chapter', 'journal-article', 'other',
#        'proceedings-article', 'book', 'dissertation', 'reference-entry',
#        'monograph', 'dataset', 'edited-book', 'report',
#        'report-component', 'book-part', 'component', 'journal-issue',
#        'book-section', 'report-series'], dtype=object)

# %%
cleaned_results_df[cleaned_results_df.flag == "Yes"]
# Out:
#                                          DOI         token_vocabulary  \
# 285316  10.14302/issn.2691-8862.jvat-20-3275                [Heidari]
# 232160            10.1007/s13139-021-00727-1                    [Kim]
# 15025                   10.1007/3418_2012_50                  [Trost]
# 20281                       10.7202/600273ar                  [André]
# 379005         10.1080/07078552.2016.1249124  [Wood, Ellen, Meiksins]
# ...                                      ...                      ...
# 115366              10.1002/ange.19290422002                 [Smekal]
# 115328                    10.1007/bf02671243               [Soboyejo]
# 57263            10.1007/978-94-011-5228-0_8                 [Cruden]
# 78921              10.1016/j.esp.2009.10.001               [Mauranen]
# 388278                   10.1038/pr.2016.134                [Colombo]
#
#         token_frac_refs  total_processed_ref_len  cleaned_references_length  \
# ...

# %% [markdown]
# * Get ISSNs for the flagged DOIs and group these

# %%
cleaned_results_df[cleaned_results_df.work_type != "journal-article"].head(10)
# Out:
#                                 DOI  \
# 241427    10.1002/essoar.10508278.1
# 34061   10.1007/978-1-4615-9585-4_1
# 128786     10.1007/3-7643-7585-x_16
# 400483  10.1007/978-1-349-04627-0_1
# 457146  10.1007/978-3-7091-3727-7_2
# 24157   10.1007/978-3-642-49715-5_1
# 239144    10.1017/9781108939201.020
# 408023  10.1007/978-981-287-733-8_7
# 231941    10.1002/essoar.10510183.1
# 458456  10.1007/978-3-663-08928-5_3
#
#                                          token_vocabulary  token_frac_refs  \
# 241427  [comatyponpdfplu, sinternalmodelp, lusxmlimplAut]         0.998131
# 34061                            [Theodosius, Dobzhansky]         0.998012
# 128786                                              [Aki]         0.995556
# 400483                                              [GLS]         0.995455
# 457146                                              [aaO]         0.994792
# 24157                                              [Rein]         0.994186
# ...

# %%
cleaned_results_df[(cleaned_results_df['flag']  == "Yes") & (cleaned_results_df['work_type'] == "journal-article")]
# Out:
#                                          DOI         token_vocabulary  \
# 285316  10.14302/issn.2691-8862.jvat-20-3275                [Heidari]
# 232160            10.1007/s13139-021-00727-1                    [Kim]
# 20281                       10.7202/600273ar                  [André]
# 379005         10.1080/07078552.2016.1249124  [Wood, Ellen, Meiksins]
# 265175              10.11600/rlcsnj.19.1.e01              [Rodríguez]
# ...                                      ...                      ...
# 328907             10.1007/s11426-018-9382-3                    [Zhu]
# 115366              10.1002/ange.19290422002                 [Smekal]
# 115328                    10.1007/bf02671243               [Soboyejo]
# 78921              10.1016/j.esp.2009.10.001               [Mauranen]
# 388278                   10.1038/pr.2016.134                [Colombo]
#
#         token_frac_refs  total_processed_ref_len  cleaned_references_length  \
# ...
